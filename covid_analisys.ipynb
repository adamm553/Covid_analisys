# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Import i przedstawienie podstawowych informacji o zbiorze

# %%
covid = pd.read_csv('owid-covid-data.csv')
covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
covid.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 219170      ZWE    Africa  Zimbabwe  2022-09-21     257156.0        0.0
# 219171      ZWE    Africa  Zimbabwe  2022-09-22     257259.0      103.0
# 219172      ZWE    Africa  Zimbabwe  2022-09-23     257289.0       30.0
# 219173      ZWE    Africa  Zimbabwe  2022-09-24     257318.0       29.0
# 219174      ZWE    Africa  Zimbabwe  2022-09-25     257340.0       22.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 219170              31.000        5598.0         0.0                0.286
# 219171              45.714        5598.0         0.0                0.286
# 219172              50.000        5599.0         1.0                0.429
# 219173              47.143        5599.0         0.0                0.143
# 219174              49.143        5599.0         0.0                0.143
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219175 entries, 0 to 219174
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    219175 non-null  object
#  1   continent                                   206567 non-null  object
#  2   location                                    219175 non-null  object
#  3   date                                        219175 non-null  object
#  4   total_cases                                 210222 non-null  float64
#  5   new_cases                                   209932 non-null  float64
#  6   new_cases_smoothed                          208736 non-null  float64
#  7   total_deaths                                191138 non-null  float64
#  8   new_deaths                                  191051 non-null  float64
# ...

# %%
covid.describe().T
# Out:
#                                             count          mean           std  \
# total_cases                              210222.0  4.216465e+06  2.643383e+07
# new_cases                                209932.0  1.248387e+04  8.614269e+04
# new_cases_smoothed                       208736.0  1.252687e+04  8.425393e+04
# total_deaths                             191138.0  7.241844e+04  3.732846e+05
# new_deaths                               191051.0  1.420666e+02  7.412423e+02
# ...                                           ...           ...           ...
# human_development_index                  175149.0  7.248701e-01  1.496919e-01
# excess_mortality_cumulative_absolute       7271.0  4.665339e+04  1.300163e+05
# excess_mortality_cumulative                7271.0  9.763841e+00  1.368896e+01
# excess_mortality                           7316.0  1.454518e+01  2.676104e+01
# excess_mortality_cumulative_per_million    7271.0  1.283087e+03  1.694885e+03
#
# ...

# %%
covid.location.nunique()
#Liczba krajów
# Out:
# 244

# %%
covid.continent.nunique()
#Liczba kontynentów
# Out:
# 6

# %% [markdown]
# # Strefa przerabiania zbioru

# %%
covid = covid[covid['continent'].notna()]

# %%
continents = covid['continent'].unique().tolist()
continents
# Out:
# ['Asia', 'Europe', 'Africa', 'North America', 'South America', 'Oceania']

# %%
covid.groupby('location').total_cases.max()
# Out:
# location
# Afghanistan          198416.0
# Africa             12348987.0
# Albania              331976.0
# Algeria              270641.0
# Andorra               46147.0
#                      ...
# Western Sahara            NaN
# World             614998361.0
# Yemen                 11935.0
# Zambia               333439.0
# Zimbabwe             257340.0
# Name: total_cases, Length: 244, dtype: float64

# %%
covid.total_deaths.d

# %% [markdown]
# # Największy wynik na danym kontynencie

# %%
cases = covid.groupby('continent').total_cases.max()
cases
# Out:
# continent
# Africa            4017552.0
# Asia             44572243.0
# Europe           35149836.0
# North America    96070980.0
# Oceania          10204195.0
# South America    34624427.0
# Name: total_cases, dtype: float64

# %%
plt.bar(cases.index, cases)
plt.title("Najwyższy wynik na danym kontynencie")
plt.xlabel("Kontynent")
plt.xticks(rotation='vertical')
plt.ylabel("Liczba")
plt.yticks()
plt.show()

# %% [markdown]
# # Kraj z największą ilością potwierdzonych przypadków znajduje się w Ameryce Północnej

# %% [markdown]
# # Sumaryczna ilość potwierdzonych zakażeń Covid-19 według kontynentu

# %%
covid['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
wock = covid.groupby('location').max()['total_cases']
datas = wock[['Africa', 'Asia','Europe', 'South America', 'North America', 'Oceania']]
# Out:
# C:\Users\TheKi\AppData\Local\Temp\ipykernel_2328\1645985937.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   wock = covid.groupby('location').max()['total_cases']

# %%
plt.pie(datas, labels=datas.index)
plt.show()

# %% [markdown]
# # Najwięcej potwierdzonych zakażeń jest w Europie i Azji. Jest to ponad połowa wszystkich światowych zakażeń

# %% [markdown]
# # Minimalny i maksymalny stosunek ilości zgonów do ilości zakażeń

# %%
covid['pct'] = (covid['total_deaths'] / covid['total_cases'])*100

# %%
covid
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 219170      ZWE    Africa     Zimbabwe  2022-09-21     257156.0        0.0
# 219171      ZWE    Africa     Zimbabwe  2022-09-22     257259.0      103.0
# 219172      ZWE    Africa     Zimbabwe  2022-09-23     257289.0       30.0
# 219173      ZWE    Africa     Zimbabwe  2022-09-24     257318.0       29.0
# 219174      ZWE    Africa     Zimbabwe  2022-09-25     257340.0       22.0
#
# ...

# %%
con_min = round(covid.groupby('location').min(), 2)['pct']
con_max = round(covid.groupby('location').max(), 2)['pct']
datas_min = con_min[['Africa', 'Asia','Europe', 'South America', 'North America', 'Oceania']]
datas_max = con_max[['Africa', 'Asia','Europe', 'South America', 'North America', 'Oceania']]
# Out:
# C:\Users\TheKi\AppData\Local\Temp\ipykernel_2328\2695957307.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   con_min = round(covid.groupby('location').min(), 2)['pct']
# C:\Users\TheKi\AppData\Local\Temp\ipykernel_2328\2695957307.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   con_max = round(covid.groupby('location').max(), 2)['pct']

# %%
labels = datas_min.index
x = np.arange(len(labels)) 
width = 0.35
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, datas_min, width, label='minimalny stosunek')
rects2 = ax.bar(x + width/2, datas_max, width, label='maksymalny stosunek')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Minimalny i maksymalny stosunek ilości zgonów do ilości zakażeń na kontynencie')
ax.set_xticks(x, labels, rotation='vertical')
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %% [markdown]
# # Największe zróżnicowanie zgonów do zakażeń było zaobserwowane w Europie. Tam też rożnica pomiędzy największym, a najmniejszym stosunkiem jest największa

# %% [markdown]
# # Rozwój pandemii COVID-19 w Polsce

# %%
wock_to_poland = covid[covid['location']=='Poland']
wock_to_poland['month_year'] = wock_to_poland['date'].str[0:7]
wock_to_poland.head()
# Out:
# C:\Users\TheKi\AppData\Local\Temp\ipykernel_2328\4110224414.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wock_to_poland['month_year'] = wock_to_poland['date'].str[0:7]
#        iso_code continent location        date  total_cases  new_cases  \
# 158119      POL    Europe   Poland  2020-03-04          1.0        1.0
# 158120      POL    Europe   Poland  2020-03-05          1.0        0.0
# 158121      POL    Europe   Poland  2020-03-06          5.0        4.0
# 158122      POL    Europe   Poland  2020-03-07          5.0        0.0
# 158123      POL    Europe   Poland  2020-03-08         11.0        6.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
mont = wock_to_poland.groupby('month_year').sum()
values = mont['new_cases']

# %%
plt.plot(values.index, values)
plt.xlabel('Miesiąc i rok')
plt.xticks(rotation='vertical')
plt.ylabel("Liczba nowych zakażeń")
plt.show()

# %% [markdown]
# # Na wykresie można zauważyć, że największe liczby zakażeń były obserwowane w okresie jesienno-zimowym
